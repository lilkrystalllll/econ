# %%
import numpy as np # linear algebra 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# stats models: regression fitting
import statsmodels.formula.api as smf
# data visualization
import seaborn as sns
import scipy
import statsmodels.api as sm

# %%
df = pd.read_csv('sleep75.csv')
df.shape
# Out:
# (706, 34)

# %%
df.head()
# Out:
#    age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0   32      0     1       0.0       0.0    12        0       0     1   3529
# 1   31      0     2       0.0       0.0    14     9500       1     1   2140
# 2   44      0     3       0.0       0.0    17    42500       1     1   4595
# 3   30      0     4       0.0       0.0    12    42500       1     1   3211
# 4   64      0     5       0.0       0.0    14     2500       1     1   4052
#
#    ...  spwrk75  totwrk  union  worknrm  workscnd  exper  yngkid  yrsmarr  \
# 0  ...        0    3438      0     3438         0     14       0       13
# 1  ...        0    5020      0     5020         0     11       0        0
# 2  ...        1    2815      0     2815         0     21       0        0
# 3  ...        1    3786      0     3786         0     12       0       12
# 4  ...        1    2580      0     2580         0     44       0       33
#
#       hrwage  agesq
# 0   7.070004   1024
# 1   1.429999    961
# ...

# %%
# подгонка плоскости
fitted_plane = smf.ols(formula='sleep~age+smsa', data=df).fit()
# коэффициенты с округлением
fitted_plane.params.round(2)
# Out:
# Intercept    3151.38
# age             3.61
# smsa          -62.83
# dtype: float64

# %% [markdown]
# Задание 1

# %%
data1 = pd.read_csv('wage2.csv')
data1.shape
# Out:
# (935, 17)

# %%
df.head()
# Out:
#    age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0   32      0     1       0.0       0.0    12        0       0     1   3529
# 1   31      0     2       0.0       0.0    14     9500       1     1   2140
# 2   44      0     3       0.0       0.0    17    42500       1     1   4595
# 3   30      0     4       0.0       0.0    12    42500       1     1   3211
# 4   64      0     5       0.0       0.0    14     2500       1     1   4052
#
#    ...  spwrk75  totwrk  union  worknrm  workscnd  exper  yngkid  yrsmarr  \
# 0  ...        0    3438      0     3438         0     14       0       13
# 1  ...        0    5020      0     5020         0     11       0        0
# 2  ...        1    2815      0     2815         0     21       0        0
# 3  ...        1    3786      0     3786         0     12       0       12
# 4  ...        1    2580      0     2580         0     44       0       33
#
#       hrwage  agesq
# 0   7.070004   1024
# 1   1.429999    961
# ...

# %%
# подгонка плоскости
fitted_line = smf.ols(formula='np.log(wage)~IQ+south', data=data1).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# Intercept    6.01
# IQ           0.01
# south       -0.12
# dtype: float64

# %%
# R^2
fitted_line.rsquared.round(3) #интерпретация:
# Out:
# 0.116

# %%
#adj R^2
fitted_line.rsquared_adj.round(3)
# Out:
# 0.115

# %% [markdown]
# Задание 2

# %%
data2 = pd.read_csv('sleep75.csv')
data2.shape
# Out:
# (706, 34)

# %%
data2.head()
# Out:
#    age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0   32      0     1       0.0       0.0    12        0       0     1   3529
# 1   31      0     2       0.0       0.0    14     9500       1     1   2140
# 2   44      0     3       0.0       0.0    17    42500       1     1   4595
# 3   30      0     4       0.0       0.0    12    42500       1     1   3211
# 4   64      0     5       0.0       0.0    14     2500       1     1   4052
#
#    ...  spwrk75  totwrk  union  worknrm  workscnd  exper  yngkid  yrsmarr  \
# 0  ...        0    3438      0     3438         0     14       0       13
# 1  ...        0    5020      0     5020         0     11       0        0
# 2  ...        1    2815      0     2815         0     21       0        0
# 3  ...        1    3786      0     3786         0     12       0       12
# 4  ...        1    2580      0     2580         0     44       0       33
#
#       hrwage  agesq
# 0   7.070004   1024
# 1   1.429999    961
# ...

# %%
# подгонка плоскости
fitted_plane = smf.ols(formula='sleep~totwrk+male+marr+south', data=data2).fit()
# коэффициенты с округлением
fitted_plane.params.round(2)
# Out:
# Intercept    3525.85
# totwrk         -0.17
# male           88.63
# marr           36.87
# south         116.31
# dtype: float64

# %%
TSS = ((df['sleep'] - np.mean(df['sleep']))**2).sum()
TSS.round(3)
# Out:
# 139239835.763

# %%
fitted_plane.centered_tss
# Out:
# 139239835.76345608

# %%
# R^2
fitted_plane.rsquared.round(3) #интерпретация: Коэффициент детерминации изменяется в диапазоне от − ∞ до 1. Если он равен 1, это соответствует идеальной модели, когда все точки наблюдений лежат точно на линии регрессии, т.е. сумма квадратов их отклонений равна 0. Если коэффициент детерминации равен 0, это означает, что связь между переменными регрессионной модели отсутствует, и вместо нее для оценки значения выходной переменной можно использовать простое среднее ее наблюдаемых значений.
# Out:
# 0.123

# %%
 #adj R^2
fitted_plane.rsquared_adj.round(3)
# Out:
# 0.118

# %% [markdown]
# ## Задание 3
# для датасета wage2 оцените регрессию log(wage) на age, south & urban. вычислите TSS, ESS, RSS

# %%
data3 = pd.read_csv('wage2.csv')
data3.shape
data3.head()
# Out:
#    wage  hours   IQ  KWW  educ  exper  tenure  age  married  black  south  \
# 0   769     40   93   35    12     11       2   31        1      0      0
# 1   808     50  119   41    18     11      16   37        1      0      0
# 2   825     40  108   46    14     11       9   33        1      0      0
# 3   650     40   96   32    12     13       7   32        1      0      0
# 4   562     40   74   27    11     14       5   34        1      0      0
#
#    urban  sibs  brthord  meduc  feduc     lwage
# 0      1     1      2.0    8.0    8.0  6.645091
# 1      1     1      NaN   14.0   14.0  6.694562
# 2      1     1      2.0   14.0   14.0  6.715384
# 3      1     4      3.0   12.0   12.0  6.476973
# 4      1    10      6.0    6.0   11.0  6.331502

# %%
# подгонка плоскости
fitted_plane = smf.ols(formula='np.log(wage)~age+south+urban', data=data3).fit()
# коэффициенты с округлением
fitted_plane.params.round(2)
# Out:
# Intercept    6.00
# age          0.02
# south       -0.15
# urban        0.17
# dtype: float64

# %%
fitted_plane.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           np.log(wage)   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.094
# Method:                 Least Squares   F-statistic:                     33.18
# Date:                Tue, 23 May 2023   Prob (F-statistic):           2.23e-20
# Time:                        12:28:24   Log-Likelihood:                -470.15
# No. Observations:                 935   AIC:                             948.3
# Df Residuals:                     931   BIC:                             967.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.9968      0.143     41.979      0.000       5.716       6.277
# ...

# %%
fitted_plane.params
# Out:
# Intercept    5.996819
# age          0.021421
# south       -0.150651
# urban        0.174126
# dtype: float64

# %%
#ESS
ESS = fitted_plane.ess
ESS
# Out:
# 16.00034440965925

# %%
#RSS
fitted_plane.ssr.round(2)
# Out:
# 149.66

# %%
TSS = fitted_plane.centered_tss
TSS
# Out:
# 165.65628831877103

# %%
R2=ESS/TSS
R2
# Out:
# 0.09658760661635686

# %%
fitted_plane.rsquared.round(2)
# Out:
# 0.1

# %%
fitted_plane.rsquared_adj.round(2)
# Out:
# 0.09

# %% [markdown]
# ## Задание 4
# для датасета sleep75 рассмотрим регрессию sleep на totwrk, age, male, smsa
# для наблюдения с номером 3 найти фактическое значение зависимой переменной, предсказанное значение и остаток. ответ округлить до 3-х десятичных

# %%
data4 = pd.read_csv('sleep75.csv')
data4.shape
# Out:
# (706, 34)

# %%
data4.head()
# Out:
#    age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0   32      0     1       0.0       0.0    12        0       0     1   3529
# 1   31      0     2       0.0       0.0    14     9500       1     1   2140
# 2   44      0     3       0.0       0.0    17    42500       1     1   4595
# 3   30      0     4       0.0       0.0    12    42500       1     1   3211
# 4   64      0     5       0.0       0.0    14     2500       1     1   4052
#
#    ...  spwrk75  totwrk  union  worknrm  workscnd  exper  yngkid  yrsmarr  \
# 0  ...        0    3438      0     3438         0     14       0       13
# 1  ...        0    5020      0     5020         0     11       0        0
# 2  ...        1    2815      0     2815         0     21       0        0
# 3  ...        1    3786      0     3786         0     12       0       12
# 4  ...        1    2580      0     2580         0     44       0       33
#
#       hrwage  agesq
# 0   7.070004   1024
# 1   1.429999    961
# ...

# %%
# подгонка плоскости
fitted_plane = smf.ols(formula='sleep~totwrk+age+male+smsa', data=data4).fit()
# коэффициенты с округлением
fitted_plane.params.round(2)
# Out:
# Intercept    3494.22
# totwrk         -0.17
# age             2.81
# male           86.91
# smsa          -75.29
# dtype: float64

# %%
ind = np.array([3])-1

# %%
#предсказанное
fitted_plane.fittedvalues[ind].round(3)
# Out:
# 2    3157.311
# dtype: float64

# %%
#фактическое
data4['sleep'].iloc[ind].round(3)
# Out:
# 2    2670
# Name: sleep, dtype: int64

# %%
#остатки
fitted_plane.resid[ind].round(3)
# Out:
# 2   -487.311
# dtype: float64

# %%
ind = np.array([1, 4, 6, 10, 508, 700])-1

# %%
# Предсказанные
fitted_plane.fittedvalues[ind]
# Out:
# 0      3094.453743
# 3      2943.579539
# 5      3494.142891
# 9      3111.983473
# 507    3476.913947
# 699    3295.398425
# dtype: float64

# %% [markdown]
# ## .1.2 Задача
# Для набора данных Labour рассмотрим регрессию log(output) на log(capital) и log(labour) Ниже приведены коэффициенты подогнанной модели. Для каждого наблюдения вычислите предсказанное значение и остатки. Ответ округлите до 2-х десятичных знаков.

# %%
df_la = pd.read_csv('Labour.csv')
df_la.shape
# Out:
# (569, 4)

# %%
# подгонка плоскости
fitted_la = smf.ols(formula='np.log(output)~np.log(capital)+np.log(labour)', data=df_la).fit()
# коэффициенты с округлением
fitted_la.params.round(2)
# Out:
# Intercept         -1.71
# np.log(capital)    0.21
# np.log(labour)     0.71
# dtype: float64

# %%
df_la.head().round(2)
# Out:
#    capital  labour  output   wage
# 0     2.61     184    9.25  43.08
# 1     1.32      91    3.66  27.78
# 2    22.09     426   28.78  44.47
# 3    10.74      72    4.12  39.73
# 4     1.16      46    2.89  34.65

# %%
ind = np.array([1, 2, 3, 4, 5, 6])-1

# %%
# Предсказанные
fitted_la.fittedvalues[ind].round(2)
# Out:
# 0    2.22
# 1    1.57
# 2    3.26
# 3    1.84
# 4    1.06
# 5    5.85
# dtype: float64

# %%
# Остатки
fitted_la.resid[ind].round(2)
# Out:
# 0    0.01
# 1   -0.27
# 2    0.10
# 3   -0.42
# 4    0.00
# 5    0.33
# dtype: float64

# %% [markdown]
# 1.1.1 Задача
# Для набора данных sleep75 рассмотрим регрессию sleep на totwrk, age, male и log(hrwage). Ниже приведены коэффициенты подогнанной модели

# %%
df_sl = pd.read_csv('sleep75.csv')
df_sl.shape
# Out:
# (706, 34)

# %%
# подгонка плоскости
sleep_eq = smf.ols(formula='sleep~totwrk+age+male+np.log(hrwage)', data=df_sl).fit()
# коэффициенты с округлением
sleep_eq.params.round(2)
# Out:
# Intercept         3525.14
# totwrk              -0.16
# age                  1.62
# male                51.84
# np.log(hrwage)      -9.88
# dtype: float64

# %%
df_sl.head()
# Out:
#    age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0   32      0     1       0.0       0.0    12        0       0     1   3529
# 1   31      0     2       0.0       0.0    14     9500       1     1   2140
# 2   44      0     3       0.0       0.0    17    42500       1     1   4595
# 3   30      0     4       0.0       0.0    12    42500       1     1   3211
# 4   64      0     5       0.0       0.0    14     2500       1     1   4052
#
#    ...  spwrk75  totwrk  union  worknrm  workscnd  exper  yngkid  yrsmarr  \
# 0  ...        0    3438      0     3438         0     14       0       13
# 1  ...        0    5020      0     5020         0     11       0        0
# 2  ...        1    2815      0     2815         0     21       0        0
# 3  ...        1    3786      0     3786         0     12       0       12
# 4  ...        1    2580      0     2580         0     44       0       33
#
#       hrwage  agesq
# 0   7.070004   1024
# 1   1.429999    961
# ...

# %%
ind = np.array([1, 2, 3, 4, 5, 6])-1

# %%
# Предсказанные
sleep_eq.fittedvalues[ind]
# Out:
# 0    3065.014012
# 1    2828.639905
# 2    3172.591056
# 3    2951.770145
# 4    3262.088252
# 5    3423.350459
# dtype: float64

# %%
# Фактические
df_sl['sleep'].iloc[ind]
# Out:
# 0    3113
# 1    2920
# 2    2670
# 3    3083
# 4    3448
# 5    4063
# Name: sleep, dtype: int64

# %% [markdown]
# ## Задание 5

# %%
df=pd.read_csv('sleep75.csv')
df.shape
# Out:
# (706, 34)

# %%
df.head()
# Out:
#    age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0   32      0     1       0.0       0.0    12        0       0     1   3529
# 1   31      0     2       0.0       0.0    14     9500       1     1   2140
# 2   44      0     3       0.0       0.0    17    42500       1     1   4595
# 3   30      0     4       0.0       0.0    12    42500       1     1   3211
# 4   64      0     5       0.0       0.0    14     2500       1     1   4052
#
#    ...  spwrk75  totwrk  union  worknrm  workscnd  exper  yngkid  yrsmarr  \
# 0  ...        0    3438      0     3438         0     14       0       13
# 1  ...        0    5020      0     5020         0     11       0        0
# 2  ...        1    2815      0     2815         0     21       0        0
# 3  ...        1    3786      0     3786         0     12       0       12
# 4  ...        1    2580      0     2580         0     44       0       33
#
#       hrwage  agesq
# 0   7.070004   1024
# 1   1.429999    961
# ...

# %%
# подгонка плоскости
fitted_plane = smf.ols(formula='sleep~totwrk+educ+selfe+yrsmarr+age+male+spwrk75', data=df).fit()
# коэффициенты с округлением
fitted_plane.params.round(2)
# Out:
# Intercept    3635.22
# totwrk         -0.17
# educ          -11.97
# selfe          28.06
# yrsmarr        -0.99
# age             2.52
# male           88.74
# spwrk75        -0.94
# dtype: float64

# %%
fitted_plane.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sleep   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                  0.114
# Method:                 Least Squares   F-statistic:                     13.92
# Date:                Tue, 28 Mar 2023   Prob (F-statistic):           6.04e-17
# Time:                        01:33:03   Log-Likelihood:                -5259.5
# No. Observations:                 706   AIC:                         1.053e+04
# Df Residuals:                     698   BIC:                         1.057e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3635.2162    115.602     31.446      0.000    3408.247    3862.185
# ...

# %% [markdown]
# ## Задание 5 расшифровка

# %% [markdown]
# уравнение y=a*bx level-level коэфф б равен изменению значения переменной y при увеличении значения переменной x на 1
# уравнение lny=a+blnX log-log уравнение b- эластичность переменной y по отношению к переменной x и приблизительно равен процентному изменению значения y при увеличении значения переменной X на 1%
#
# уравнение lny=a+bX log-level уравнение коэфф б (полуэластичность) при увеличении значения переменной X на 1 значение переменной Y изменяется приблизительно на 100*B%
#
# уравнение y=a+bLnX level-log уравнение. при увеличении значения переменной X на 1% значение переменной Y изменяется приблизительно на B/100 единиц
